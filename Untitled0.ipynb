# %%
3+4
# Out:
# 7

# %%
import yfinance as yf #collect data from yfinance
import pandas as pd #data anlaysis
import matplotlib.pyplot as plt #data visualisation
import seaborn as sns #data visualisation

# %%
start_date = "2025-01-01"
end_date = "2025-10-01"

# %%
circle = yf.download("CRCL",start_date, end_date )
# Out:
# /tmp/ipython-input-3746122814.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   circle = yf.download("CRCL",start_date, end_date )
# [*********************100%***********************]  1 of 1 completed

# %%
circle
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            CRCL        CRCL        CRCL        CRCL      CRCL
# Date
# 2025-06-05   83.230003  103.750000   64.000000   69.000000  47192000
# 2025-06-06  107.699997  123.514999   92.949997   96.389999  60706300
# 2025-06-09  115.250000  138.570007  108.400002  132.720001  45521100
# 2025-06-10  105.910004  115.000000  101.510002  115.000000  25517800
# 2025-06-11  117.199997  120.489998  106.500000  107.000000  26481400
# ...                ...         ...         ...         ...       ...
# 2025-09-24  131.580002  136.339996  130.039993  133.729996   9155800
# 2025-09-25  124.660004  130.259995  124.300003  128.990005   7729900
# 2025-09-26  126.989998  128.490005  122.830002  125.419998   5467800
# 2025-09-29  133.660004  137.800003  128.500000  129.500000  10474600
# 2025-09-30  132.580002  137.990005  132.369995  136.199997   7965500
#
# [81 rows x 5 columns]

# %%
GOOGL = yf.download("GOOGL",start_date, end_date )
# Out:
# /tmp/ipython-input-438140828.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   GOOGL = yf.download("GOOGL",start_date, end_date )
# [*********************100%***********************]  1 of 1 completed

# %%
GOOGL
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker           GOOGL       GOOGL       GOOGL       GOOGL     GOOGL
# Date
# 2025-01-02  188.814423  191.376078  186.890702  190.030459  20370800
# 2025-01-03  191.166748  192.582147  189.362632  190.748115  18596200
# 2025-01-06  196.230240  197.575859  193.220065  193.349632  29563600
# 2025-01-07  194.854752  200.346841  193.967644  196.469482  26487200
# 2025-01-08  193.319733  195.652125  191.754842  191.944227  24864800
# ...                ...         ...         ...         ...       ...
# 2025-09-24  247.139999  252.350006  246.440002  251.660004  28201000
# 2025-09-25  245.789993  246.490005  240.740005  244.399994  31020400
# 2025-09-26  246.539993  249.419998  245.970001  247.070007  18503200
# 2025-09-29  244.050003  251.149994  242.770004  247.850006  32505800
# 2025-09-30  243.100006  243.289993  239.250000  242.809998  34724300
#
# [186 rows x 5 columns]

# %%
Meta = yf.download("Meta",start_date, end_date )
# Out:
# /tmp/ipython-input-4260071859.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   Meta = yf.download("Meta",start_date, end_date )
# [*********************100%***********************]  1 of 1 completed

# %%
Meta
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            META        META        META        META      META
# Date
# 2025-01-02  597.843506  603.500275  586.450136  588.345672  12682300
# 2025-01-03  603.220947  608.079593  595.020072  603.350649  11436800
# 2025-01-06  628.731384  629.519521  604.208649  610.404199  14560800
# 2025-01-07  616.450073  630.626919  606.812551  630.227888  12071500
# 2025-01-08  609.296753  615.003455  601.385240  611.970561  10085800
# ...                ...         ...         ...         ...       ...
# 2025-09-24  760.659973  761.109985  752.530029  757.500000   8828200
# 2025-09-25  748.909973  756.770020  744.549988  753.450012  10591100
# 2025-09-26  743.750000  751.929993  737.349976  750.000000   9696300
# 2025-09-29  743.400024  750.780029  739.150024  748.719971   9246800
# 2025-09-30  734.380005  742.969971  726.299988  742.250000  16226800
#
# [186 rows x 5 columns]

# %%
COIN = yf.download("COIN",start_date, end_date )
# Out:
# /tmp/ipython-input-2914527160.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   COIN = yf.download("COIN",start_date, end_date )
# [*********************100%***********************]  1 of 1 completed

# %%
COIN
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            COIN        COIN        COIN        COIN      COIN
# Date
# 2025-01-02  257.209991  262.309998  251.000000  256.480011   6289500
# 2025-01-03  270.649994  271.589996  258.589996  259.890015   5990800
# 2025-01-06  287.760010  293.600006  271.750000  279.070007  10835000
# 2025-01-07  264.329987  287.579987  260.239990  286.739990  11614700
# 2025-01-08  260.010010  267.000000  252.990005  263.880005   5951100
# ...                ...         ...         ...         ...       ...
# 2025-09-24  321.769989  327.320007  320.760010  323.760010   4869800
# 2025-09-25  306.690002  317.989990  304.359985  314.329987   8865300
# 2025-09-26  312.589996  314.239990  303.399994  308.579987   6714800
# 2025-09-29  333.989990  334.380005  316.350006  318.010010  12066100
# 2025-09-30  337.489990  338.100006  329.660004  330.000000   6674700
#
# [186 rows x 5 columns]

# %%
PYPL = yf.download("PYPL",start_date, end_date )
# Out:
# /tmp/ipython-input-3289398193.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   PYPL = yf.download("PYPL",start_date, end_date )
# [*********************100%***********************]  1 of 1 completed

# %%
PYPL
# Out:
# Price           Close       High        Low       Open    Volume
# Ticker           PYPL       PYPL       PYPL       PYPL      PYPL
# Date
# 2025-01-02  86.180000  86.940002  84.820000  85.834999   6224500
# 2025-01-03  87.599998  87.699997  86.309998  86.730003   6132500
# 2025-01-06  89.529999  90.089996  87.720001  88.019997   7869200
# 2025-01-07  87.970001  89.970001  87.599998  89.529999   6080800
# 2025-01-08  87.940002  88.230003  86.790001  88.059998   7400000
# ...               ...        ...        ...        ...       ...
# 2025-09-24  67.860001  68.580002  67.440002  67.650002   9180600
# 2025-09-25  66.739998  67.489998  66.199997  67.260002  10773700
# 2025-09-26  67.300003  67.629997  66.320000  67.000000   8431600
# 2025-09-29  69.680000  71.260002  67.889999  67.959999  28497000
# 2025-09-30  67.059998  69.830002  66.849998  69.824997  21464800
#
# [186 rows x 5 columns]

# %%
CIFR = yf.download("CIFR",start_date, end_date )
# Out:
# /tmp/ipython-input-224878051.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   CIFR = yf.download("CIFR",start_date, end_date )
# [*********************100%***********************]  1 of 1 completed

# %%
CIFR
# Out:
# Price       Close    High     Low    Open     Volume
# Ticker       CIFR    CIFR    CIFR    CIFR       CIFR
# Date
# 2025-01-02   4.83   5.040   4.670   4.840    7396300
# 2025-01-03   5.57   5.580   4.855   4.900    9916000
# 2025-01-06   5.85   5.970   5.500   5.740    8576500
# 2025-01-07   5.39   5.830   5.200   5.830    6358200
# 2025-01-08   5.05   5.295   4.950   5.250    5836000
# ...           ...     ...     ...     ...        ...
# 2025-09-24  14.14  15.540  13.870  14.805   46323300
# 2025-09-25  11.66  13.600  11.410  13.590  155920100
# 2025-09-26  11.47  12.350  11.010  11.495   94631700
# 2025-09-29  12.65  12.670  11.405  11.865   61311200
# 2025-09-30  12.59  12.760  12.140  12.720   47248700
#
# [186 rows x 5 columns]

# %%
circle["Close"] . plot(figsize = (16,8))
plt.xlabel("date")
plt.ylabel("Sprice")
plt.title("circle stock price")
# Out:
# Text(0.5, 1.0, 'circle stock price')

# %%
tickers = ["GOOGL", "COIN", "PYPL",'CIFR']
portfolio = yf.download(tickers, start_date, end_date)
# Out:
# /tmp/ipython-input-202289890.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   portfolio = yf.download(tickers, start_date, end_date)
# [*********************100%***********************]  4 of 4 completed

# %%
close = portfolio
close.head() #top 5 rowws
# Out:
# Price      Close                                      High              \
# Ticker      CIFR        COIN       GOOGL       PYPL   CIFR        COIN
# Date
# 2025-01-02  4.83  257.209991  188.814423  86.180000  5.040  262.309998
# 2025-01-03  5.57  270.649994  191.166748  87.599998  5.580  271.589996
# 2025-01-06  5.85  287.760010  196.230240  89.529999  5.970  293.600006
# 2025-01-07  5.39  264.329987  194.854752  87.970001  5.830  287.579987
# 2025-01-08  5.05  260.010010  193.319733  87.940002  5.295  267.000000
#
# Price                                Low                                     \
# Ticker           GOOGL       PYPL   CIFR        COIN       GOOGL       PYPL
# Date
# 2025-01-02  191.376078  86.940002  4.670  251.000000  186.890702  84.820000
# 2025-01-03  192.582147  87.699997  4.855  258.589996  189.362632  86.309998
# 2025-01-06  197.575859  90.089996  5.500  271.750000  193.220065  87.720001
# ...

# %%
portfolio["Close"].plot(figsize=(16,8))
# Out:
# <Axes: xlabel='Date'>

# %%
portfolio["Close"].pct_change().corr()
# Out:
# Ticker      CIFR      COIN     GOOGL      PYPL
# Ticker
# CIFR    1.000000  0.586983  0.430130  0.416030
# COIN    0.586983  1.000000  0.449167  0.419624
# GOOGL   0.430130  0.449167  1.000000  0.354582
# PYPL    0.416030  0.419624  0.354582  1.000000

# %%
corrMatrix=portfolio["Close"].pct_change().corr()
sns.heatmap(corrMatrix,annot= True)
# Out:
# <Axes: xlabel='Ticker', ylabel='Ticker'>

# %%
GOOGL["Close"] . plot(figsize = (16,8))
plt.xlabel("date")
plt.ylabel("Sprice")
plt.title("GOOGL stock price")
# Out:
# Text(0.5, 1.0, 'GOOGL stock price')
